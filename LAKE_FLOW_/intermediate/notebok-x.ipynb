# %%
df = spark.createDataFrame(
    [
        ("Alice", 25),
        ("Bob", 30),
        ("Charlie", 22),
        ("David", 28),
        ("Eve", 35)
    ],
    ["name", "age"]
)
display(df.count())

# %%
total_count=df.count()
print(total_count)

# %%
dbutils.jobs.taskValues.set("total_record", total_count)

# %%
order_id=1
dbutils.jobs.taskValues.set("order_id", order_id)
