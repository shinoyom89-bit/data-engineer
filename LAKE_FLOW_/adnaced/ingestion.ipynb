# %%
dbutils.widgets.text("tables","")
tables=dbutils.widgets.get("tables")

# %%
df=spark.read.format("parquet")\
    .load(f"/Volumes/db_jobs/default/jobs_file/{tables}.parquet")

# %%
df.write.format("delta")\
    .mode("overwrite")\
    .save(f"/Volumes/db_jobs/default/jobs_file/sink/{tables}")
